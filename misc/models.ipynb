# %%
import librosa
import os
import yt_dlp
import soundfile as sf

def trim_audio(input_file, output_dir, segment_duration=10):
    # Load the audio file
    audio, sr = librosa.load(input_file, sr=None)
    num_segments = len(audio) // (sr * segment_duration)
    
    for i in range(num_segments):
        start_sample = i * sr * segment_duration
        end_sample = (i + 1) * sr * segment_duration
        segment = audio[start_sample:end_sample]
        
        output_file = os.path.join(output_dir, f"segment_{i}.wav")
        sf.write(output_file, segment, sr)


def extract_segment(input_file, output_file, start_time, end_time):
    # Load the audio file
    audio, sr = librosa.load(input_file, sr=None)
    
    # Calculate the start and end samples
    start_sample = int(start_time * sr)
    end_sample = int(end_time * sr)
    
    # Extract the segment
    segment = audio[start_sample:end_sample]
    
    # Save the segment to a new file
    sf.write(output_file, segment, sr)

def download_audio(url, output_template):
    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',  # You can change this to other formats like 'wav', 'm4a', etc.
            'preferredquality': '192',
        }],
        'outtmpl': output_template,
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])


def resample_audio(input_file, output_file, sr=16000):
    audio, sr = sf.read(input_file)
    audio_resampled = librosa.resample(audio, orig_sr=sr, target_sr=16000)
    sf.write(output_file, audio_resampled, sr)

# %%
url = "https://www.youtube.com/watch?v=cflUoc82iUA&t=620s"
vid = url.split("shorts/")[1].split("?")[0] if "shorts" in url else url.split("?v=")[1].split("&")[0]

#1 Download audio
output_template = f"{vid}"
# download_audio(url, output_template)

# %%
#2 Download transcript
from collections import defaultdict
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptFound
allow_auto_transcript = False

transcripts = list()
try:
    tx = YouTubeTranscriptApi.list_transcripts(vid)
    languages = [t.language_code for t in tx]
    is_generated = [t.is_generated for t in tx]
    scripts = [t.fetch() for t in tx]

    for l, g, s in zip(languages, is_generated, scripts):        
        transcripts.append({"text": s, "is_generated": g, "language": l})

    
    if not allow_auto_transcript:
        for i,t in enumerate(transcripts):
            if t["is_generated"]:
                del transcripts[i]
                
    
    for i,t in enumerate(transcripts):
        # print(f"Transcript {i+1}:")
        print(f"Language: {t['language']}")
        print(f"Generated: {t['is_generated']}")
        # print(f"Text: {t['text']}")
        print("\n")
    if len(transcripts) == 0:
        print("No transcript available.")
    
except NoTranscriptFound:
    raise NoTranscriptFound("No transcript found.")
# Out:
# Language: de
# Generated: False

# %%
def binary_search(arr:list, x:float):
    left = 0
    right = len(arr) - 1

    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == x:
            return mid, arr[mid]
        elif arr[mid] < x:
            left = mid + 1
        else:
            right = mid - 1

    if right < 0:
        return left, arr[left]
    if left >= len(arr):
        return right, arr[right]
    
    if x - arr[right] <= arr[left] - x:
        return right, arr[right]
    else:
        return left, arr[left]

# %%
#3 Create segments with corresponding transcript

from collections import defaultdict


output_dir = f"segments/{vid}"
os.makedirs(output_dir, exist_ok=True)

segment_length = 10  # seconds

# Assuming `transcript` contains a list of dictionaries with 'text', 'start', and 'duration' keys
if transcript is not None:
    texts, starts, durations = zip(*[(t['text'], t['start'], t['duration']) for t in transcript])
    ends = [start + duration for start, duration in zip(starts, durations)]
    
    segments = []
    done = False
    start_idx = 0
    while not done:
        new_segment = {
            'text': [],
            'start': 0,
            'duration': 0
        }

        end_idx, end_time = binary_search(ends, segment_length)
        end_idx+=1
        
        new_text = texts[start_idx:end_idx]
        new_start = starts[start_idx]
        new_duration = end_time - new_start
        new_segment['text'] = new_text
        new_segment['start'] = new_start
        new_segment['duration'] = new_duration

        # for k,v in new_segment.items():
        #     print(k,v)
        
        segments.append(new_segment)

        if end_idx == len(ends):
            done = True
        
        start_idx = end_idx
        segment_length += 10
        

#4 Trim audio according to segments
input_file = f"{vid}.mp3"
output_dir = f"segments/{vid}"
os.makedirs(output_dir, exist_ok=True)

for segment in segments:
    start_time = segment['start']
    duration = segment['duration']
    text = segment['text']
    output_file = f"{output_dir}/segment_{start_time}.wav"
    extract_segment(input_file, output_file, start_time, start_time + duration)
    with open(f"{output_dir}/segment_{start_time}.txt", "w", encoding="utf-8") as f:
        f.write("\n".join(text))

# %%
output_dir = "segments"
os.makedirs(output_dir, exist_ok=True)
trim_audio(output_template, output_dir)

output_resampled_dir = "segments_resampled"
os.makedirs(output_resampled_dir, exist_ok=True)

for segment_file in os.listdir(output_dir):
    input_file = os.path.join(output_dir, segment_file)
    output_file = os.path.join(output_resampled_dir, segment_file)
    resample_audio(input_file, output_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 3
#       1 output_dir = "segments"
#       2 os.makedirs(output_dir, exist_ok=True)
# ----> 3 trim_audio(output_template, output_dir)
#       5 output_resampled_dir = "segments_resampled"
#       6 os.makedirs(output_resampled_dir, exist_ok=True)
#
# Cell In[98], line 8, in trim_audio(input_file, output_dir, segment_duration)
#       6 def trim_audio(input_file, output_dir, segment_duration=10):
#       7     # Load the audio file
# ----> 8     audio, sr = librosa.load(input_file, sr=None)
#      10     # Calculate the number of segments
#      11     num_segments = len(audio) // (sr * segment_duration)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\lazy_loader\__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File d:\workspace\s2t\.venv\Lib\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# File O:\Programs\Python\3_11_6\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\librosa\core\audio.py:1152
#    1148     else:
#    1149         return np.sign(x0) != np.sign(x1)  # type: ignore
# -> 1152 @guvectorize(
#    1153     [
#    1154         "void(float32[:], float32, bool_, bool_[:])",
#    1155         "void(float64[:], float64, bool_, bool_[:])",
#    1156     ],
#    1157     "(n),(),()->(n)",
#    1158     cache=True,
#    1159     nopython=True,
#    1160 )  # type: ignore
#    1161 def _zc_wrapper(
#    1162     x: np.ndarray,
#    1163     threshold: float,
#    1164     zero_pos: bool,
#    1165     y: np.ndarray,
#    1166 ) -> None:  # pragma: no cover
#    1167     """Vectorized wrapper for zero crossing stencil"""
#    1168     y[:] = _zc_stencil(x, threshold, zero_pos)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\decorators.py:203, in guvectorize.<locals>.wrap(func)
#     201 guvec = GUVectorize(func, signature, **kwargs)
#     202 for fty in ftylist:
# --> 203     guvec.add(fty)
#     204 if len(ftylist) > 0:
#     205     guvec.disable_compile()
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\gufunc.py:64, in GUFunc.add(self, fty)
#      63 def add(self, fty):
# ---> 64     self.gufunc_builder.add(fty)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\ufuncbuilder.py:258, in _BaseUFuncBuilder.add(self, sig)
#     256 else:
#     257     targetoptions = self.nb_func.targetoptions
# --> 258 cres, args, return_type = _compile_element_wise_function(
#     259     self.nb_func, targetoptions, sig)
#     260 sig = self._finalize_signature(cres, args, return_type)
#     261 self._sigs.append(sig)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\ufuncbuilder.py:176, in _compile_element_wise_function(nb_func, targetoptions, sig)
#     173 def _compile_element_wise_function(nb_func, targetoptions, sig):
#     174     # Do compilation
#     175     # Return CompileResult to test
# --> 176     cres = nb_func.compile(sig, **targetoptions)
#     177     args, return_type = sigutils.normalize_signature(sig)
#     178     return cres, args, return_type
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\ufuncbuilder.py:124, in UFuncDispatcher.compile(self, sig, locals, **targetoptions)
#     119 # Disable loop lifting
#     120 # The feature requires a real
#     121 #  python function
#     122 flags.enable_looplift = False
# --> 124 return self._compile_core(sig, flags, locals)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\np\ufunc\ufuncbuilder.py:151, in UFuncDispatcher._compile_core(self, sig, flags, locals)
#     148 with targetconfig.ConfigStack().enter(flags.copy()):
#     149     with store_overloads_on_success():
#     150         # attempt look up of existing
# --> 151         cres = self.cache.load_overload(sig, targetctx)
#     152         if cres is not None:
#     153             return cres
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\core\caching.py:633, in Cache.load_overload(self, sig, target_context)
#     628 """
#     629 Load and recreate the cached object for the given signature,
#     630 using the *target_context*.
#     631 """
#     632 # Refresh the context to ensure it is initialized
# --> 633 target_context.refresh()
#     634 with self._guard_against_spurious_io_errors():
#     635     return self._load_overload(sig, target_context)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\core\base.py:267, in BaseContext.refresh(self)
#     262 """
#     263 Refresh context with new declarations from known registries.
#     264 Useful for third-party extensions.
#     265 """
#     266 # load target specific registries
# --> 267 self.load_additional_registries()
#     269 # Populate the builtin registry, this has to happen after loading
#     270 # additional registries as some of the "additional" registries write
#     271 # their implementations into the builtin_registry and would be missed if
#     272 # this ran first.
#     273 self.install_registry(builtin_registry)
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\core\cpu.py:69, in CPUContext.load_additional_registries(self)
#      66 rtsys.initialize(self)
#      68 # Add implementations that work via import
# ---> 69 from numba.cpython import (builtins, charseq, enumimpl, # noqa F401
#      70                            hashing, heapq, iterators, # noqa F401
#      71                            listobj, numbers, rangeobj, # noqa F401
#      72                            setobj, slicing, tupleobj, # noqa F401
#      73                            unicode,) # noqa F401
#      74 from numba.core import optional # noqa F401
#      75 from numba.misc import gdb_hook, literal # noqa F401
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\cpython\charseq.py:10
#       7 from numba.core.extending import (overload, intrinsic, overload_method,
#       8                                   lower_cast, register_jitable)
#       9 from numba.core.cgutils import is_nonelike
# ---> 10 from numba.cpython import unicode
#      12 # bytes and str arrays items are of type CharSeq and UnicodeCharSeq,
#      13 # respectively.  See numpy/types/npytypes.py for CharSeq,
#      14 # UnicodeCharSeq definitions.  The corresponding data models are
#      15 # defined in numpy/datamodel/models.py. Boxing/unboxing of item types
#      16 # are defined in numpy/targets/boxing.py, see box_unicodecharseq,
#      17 # unbox_unicodecharseq, box_charseq, unbox_charseq.
#      19 s1_dtype = np.dtype('S1')
#
# File d:\workspace\s2t\.venv\Lib\site-packages\numba\cpython\unicode.py:34
#      32 from numba.core.unsafe.bytes import memcpy_region
#      33 from numba.core.errors import TypingError
# ---> 34 from numba.cpython.unicode_support import (_Py_TOUPPER, _Py_TOLOWER, _Py_UCS4,
#      35                                            _Py_ISALNUM,
#      36                                            _PyUnicode_ToUpperFull,
#      37                                            _PyUnicode_ToLowerFull,
#      38                                            _PyUnicode_ToFoldedFull,
#      39                                            _PyUnicode_ToTitleFull,
#      40                                            _PyUnicode_IsPrintable,
#      41                                            _PyUnicode_IsSpace,
#      42                                            _Py_ISSPACE,
#      43                                            _PyUnicode_IsXidStart,
#      44                                            _PyUnicode_IsXidContinue,
#      45                                            _PyUnicode_IsCased,
#      46                                            _PyUnicode_IsCaseIgnorable,
#      47                                            _PyUnicode_IsUppercase,
#      48                                            _PyUnicode_IsLowercase,
#      49                                            _PyUnicode_IsLineBreak,
#      50                                            _Py_ISLINEBREAK,
#      51                                            _Py_ISLINEFEED,
#      52                                            _Py_ISCARRIAGERETURN,
#      53                                            _PyUnicode_IsTitlecase,
#      54                                            _Py_ISLOWER,
#      55                                            _Py_ISUPPER,
#      56                                            _Py_TAB,
#      57                                            _Py_LINEFEED,
#      58                                            _Py_CARRIAGE_RETURN,
#      59                                            _Py_SPACE,
#      60                                            _PyUnicode_IsAlpha,
#      61                                            _PyUnicode_IsNumeric,
#      62                                            _Py_ISALPHA,
#      63                                            _PyUnicode_IsDigit,
#      64                                            _PyUnicode_IsDecimalDigit)
#      65 from numba.cpython import slicing
#      67 if PYVERSION in ((3, 9), (3, 10), (3, 11)):
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1504, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1476, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1612, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
from IPython.display import Audio
from matplotlib import pyplot as plt

# sample -> {"file", "audio{"file", "array", "sampling_rate"}, "text", "speaker_id","chapter_id", "id"}

segments_dir = "segments_resampled/"
for root, dirs, files in os.walk(segments_dir):
    for f in files:
        print(f)
        seg = os.path.join(root, f)
        sample = {"audio": {
                    "file": seg,
                    "array": librosa.load(seg, sr=16000)[0],
                    "sampling_rate": librosa.load(seg, sr=16000)[1]
                    }
                }
        print(sample["audio"]["array"].shape, sample["audio"]["sampling_rate"])
        fig,axs = plt.subplots(2,1, figsize=(10,10))
        axs[0].plot(sample["audio"]["array"])
        Audio(sample["audio"]["array"], rate=sample["audio"]["sampling_rate"])

        break




sample["audio"]["array"].shape

fig,axs = plt.subplots(2,1, figsize=(10,10))
axs[0].plot(sample["audio"]["array"])

# %%
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="facebook/wav2vec2-base-100h")

# %%
pipe(sample["audio"].copy())

# %%
import torch
from transformers import pipeline

device = "cuda:0" if torch.cuda.is_available() else "cpu"
pipe = pipeline(
    "automatic-speech-recognition", model="openai/whisper-base", device=device
)

# %%
pipe(sample["audio"], max_new_tokens=256)

# %%
model
